# %% [markdown]
#      1 #include <iostream>
#      2  #include <cstdlib>
#      3  #include <ctime>
#      4  using namespace std;
#      5
#      6  int main()
#      7  {
#      8      cout << "NUMBER GUESSING GAME\n\n"; // Title of the game
#      9
#     10      int computerNum, guess;
#     11      srand(time(0));
#     12      computerNum = 1 + rand() % 100;
#     13      cout << "The computer has chosen a random number: " << computerNum << endl;
#     14
#     15      cout << "I am thinking of a number between 1 to 100\n";
#     16      cout << "Can you guess what it is? Enter your guess:\n";
#     17      cin >> guess;
#     18
#     19      while (guess != computerNum)
#     20      {
#     21          if (guess > computerNum)
#     22          {
#     23              cout << "Your " << guess << " is too high, try a smaller number\n";
#     24          }
#     25          else
#     26          {
#     27              cout << "Your " << guess << " is too low, try a larger number\n";
#     28          }
#     29          cout << "Enter your guess: "; // Prompt for guess
#     30          cin >> guess;
#     31      }
#     32
#     33      cout << "Congratulations. You got it, my number was " << computerNum << endl;
#     34      cout << "Enter '0' to exit: "; // Prompt for exit
#     35      cin >> guess;
#     36      if (guess == 0)
#     37      {
#     38          cout << "Exiting the game.\n";
#     39          return 0;
#     40      }
#     41
#     42      return 0;
#     43  }
#     44
